# %% [markdown]
# # Working with Known JSON Schemas - Lab

# %% [markdown]
# ## Introduction
# In this lab you'll practice working with json files whose schema you know beforehand.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Read JSON Documentation Schemas and translate into code
# * Extract data from known json schemas
# * Write data to predefined JSON schemas

# %% [markdown]
# ## Reading a JSON Schema
#
# Here's the JSON schema provided for a section of the NY Times API:
# <img src="nytimes_movie_schema.png" width=500>
#
# or a fully expanded view:
#
# <img src="nytimes_movie_schema_detailed.png" width=500>
#
# You can see this yourself here:
# https://developer.nytimes.com/movie_reviews_v2.json#/Documentation/GET/critics/%7Bresource-type%7D.json

# %% [markdown]
# You can see that the master structure is a dictionary and has a key named 'response'. This is also a dictionary and has two keys: 'data' and 'meta'. As you continue to examine the schema hierarchy, you'll notice the vast majority in this case are dictionaries.

# %% [markdown]
# ## Loading the Data File
#
# Start by importing the json file. The sample response from the api is stored in a file **ny_times_movies.json**

# %%
import json
import pandas as pd
f = open('ny_times_movies.json')
data = json.load(f)

# %% [markdown]
# ## Loading Specific Data
#
# Create a DataFrame of the major data container within the json file, listed under the 'results' heading in the schema above.

# %%
df = pd.DataFrame(data['results'])
df.head().T
# Out:
#                                                                   0  \
# byline                                                   A.O. SCOTT
# critics_pick                                                      1
# date_updated                                    2018-10-17 02:44:23
# display_title                               Can You Ever Forgive Me
# headline          Review: Melissa McCarthy Is Criminally Good in...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating                                                       R
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-10-19
# publication_date                                         2018-10-16
# summary_short     Marielle Heller directs a true story of litera...
#
#                                                                   1  \
# byline                                               BEN KENIGSBERG
# critics_pick                                                      1
# date_updated                                    2018-10-16 11:04:03
# display_title                                            Charm City
# headline          Review: ‘Charm City’ Vividly Captures the Stre...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-04-22
# publication_date                                         2018-10-16
# summary_short     Marilyn Ness’s documentary is dedicated to the...
#
#                                                                   2  \
# byline                                                  GLENN KENNY
# critics_pick                                                      1
# date_updated                                    2018-10-16 11:04:04
# display_title       Horn from the Heart: The Paul Butterfield Story
# headline          Review: Paul Butterfield’s Story Is Told in ‘H...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-10-19
# publication_date                                         2018-10-16
# summary_short     A documentary explores the life of the blues m...
#
#                                                                   3  \
# byline                                                  A. O. SCOTT
# critics_pick                                                      0
# date_updated                                    2018-10-16 16:08:03
# display_title                               The Price of Everything
# headline          Review: ‘The Price of Everything’ Asks $56 Bil...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-10-19
# publication_date                                         2018-10-16
# summary_short     This documentary examines the global art marke...
#
#                                                                   4
# byline                                               BEN KENIGSBERG
# critics_pick                                                      0
# date_updated                                    2018-10-16 11:04:03
# display_title                                               Impulso
# headline          Review: ‘Impulso’ Goes Backstage With a Flamen...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                                   None
# publication_date                                         2018-10-16
# summary_short     This documentary follows Rocío Molina, a cutti...

# %% [markdown]
# ## How many unique critics are there?

# %%
df['byline'].nunique()
# Out:
# 8

# %% [markdown]
# ## Create a new column for the review's url. Title the column 'review_url'

# %%
df['review_url'] = df['link'].map(lambda x: x['url'])
df.head().T
# Out:
#                                                                   0  \
# byline                                                   A.O. SCOTT
# critics_pick                                                      1
# date_updated                                    2018-10-17 02:44:23
# display_title                               Can You Ever Forgive Me
# headline          Review: Melissa McCarthy Is Criminally Good in...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating                                                       R
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-10-19
# publication_date                                         2018-10-16
# summary_short     Marielle Heller directs a true story of litera...
# review_url        http://www.nytimes.com/2018/10/16/movies/can-y...
#
#                                                                   1  \
# byline                                               BEN KENIGSBERG
# critics_pick                                                      1
# date_updated                                    2018-10-16 11:04:03
# display_title                                            Charm City
# headline          Review: ‘Charm City’ Vividly Captures the Stre...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-04-22
# publication_date                                         2018-10-16
# summary_short     Marilyn Ness’s documentary is dedicated to the...
# review_url        http://www.nytimes.com/2018/10/16/movies/charm...
#
#                                                                   2  \
# byline                                                  GLENN KENNY
# critics_pick                                                      1
# date_updated                                    2018-10-16 11:04:04
# display_title       Horn from the Heart: The Paul Butterfield Story
# headline          Review: Paul Butterfield’s Story Is Told in ‘H...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-10-19
# publication_date                                         2018-10-16
# summary_short     A documentary explores the life of the blues m...
# review_url        http://www.nytimes.com/2018/10/16/movies/horn-...
#
#                                                                   3  \
# byline                                                  A. O. SCOTT
# critics_pick                                                      0
# date_updated                                    2018-10-16 16:08:03
# display_title                               The Price of Everything
# headline          Review: ‘The Price of Everything’ Asks $56 Bil...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                             2018-10-19
# publication_date                                         2018-10-16
# summary_short     This documentary examines the global art marke...
# review_url        http://www.nytimes.com/2018/10/16/movies/the-p...
#
#                                                                   4
# byline                                               BEN KENIGSBERG
# critics_pick                                                      0
# date_updated                                    2018-10-16 11:04:03
# display_title                                               Impulso
# headline          Review: ‘Impulso’ Goes Backstage With a Flamen...
# link              {'type': 'article', 'url': 'http://www.nytimes...
# mpaa_rating
# multimedia        {'type': 'mediumThreeByTwo210', 'src': 'https:...
# opening_date                                                   None
# publication_date                                         2018-10-16
# summary_short     This documentary follows Rocío Molina, a cutti...
# review_url        http://www.nytimes.com/2018/10/16/movies/impul...

# %% [markdown]
# ## How many results are in the file?

# %%
df.shape
# Out:
# (20, 12)

# %% [markdown]
# ## Summary
# Well done! Here you continued to gather practice extracting data from JSON files and transforming them into our standard tool of Pandas DataFrames.
